# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df['quality_new']=""
for i in range(df.shape[0]):
    if df['quality'][i]>=7:
        df['quality_new'][i]=1
        i+=1
    else:
        df['quality_new'][i]=0
        i+=1
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df1 = df.drop('quality',axis= 1)

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1.shape
# Out:
# (1599, 12)

# %%
df1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df1.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality_new             0
# dtype: int64

# %%
df1['quality_new'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality_new, dtype: int64

# %%
df1.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality_new              object
# dtype: object

# %%
# this is imbalancing problem..so, to overcome this, either down sampling can be done or upsampling may be applied. but as there only 217 record for 1 o/p so, downsampling the dataset will reduce the dataset to in the range of 500 rows from 1599 rows/records, which isn't a good choice. so, acc. to me, the better choice is upsampling which will increase size of dataset n hence, a good model can be formed..

# %%
# so,for upsampling, im going to use smote here..

# %%
count =1
plt.figure(figsize=(15,15),facecolor='orange')
for i in df1:
    plt.subplot(3,4,count)
    sns.distplot(df[i])
    plt.xlabel(i)
    count+=1
    plt.tight_layout

# %%
# it shows there are a lot of features which are skewed.

# %%
count =1
plt.figure(figsize=(15,15),facecolor='orange')
for i in df1:
    plt.subplot(3,4,count)
    sns.boxplot(df1[i])
    plt.xlabel(i)
    count+=1
    plt.tight_layout

# %%
#residual sugar has highest number of outliers. other features have alsooutliers.

# %%
df1.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality_new             2.129363
# dtype: float64

# %%
df1.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# ...

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# it means as the maximum correlation among features is less than 0.7. so, they can be considered independent. but it should be quantified by vif values.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# lets remove outliers first by zscore

# %%
from scipy.stats import zscore

# %%
x=df1.drop('quality_new',axis=1)
y=df1['quality_new']

# %%
(np.abs(zscore(x))>3).all()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# dtype: bool

# %%
ind = np.where(np.abs(zscore(x))>3)
ind
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          467,  480,  480,  494,  515,  544,  554,  554,  555,  555,  557,
#          557,  568,  584,  588,  591,  595,  608,  614,  636,  639,  649,
#          649,  651,  652,  652,  652,  672,  672,  684,  690,  692,  692,
#          695,  723,  724,  730,  754,  776,  777,  795,  821,  836,  837,
#          889,  911,  917,  923,  925,  926,  982, 1017, 1018, 1043, 1051,
#         1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154,
#         1165, 1175, 1186, 1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269,
# ...

# %%
df1.drop(df1.index[ind[0]],inplace=True)

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#hence, outliers removed

# %%
x1= df1.drop('quality_new',axis=1)
y1=df1['quality_new']
x1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1.skew()
# Out:
# fixed acidity           0.820879
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          2.450707
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality_new             2.103030
# dtype: float64

# %%
# hence, power transformation with yeo-johnsonmethod is used here.

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pow= PowerTransformer(method='yeo-johnson')
x2=pow.fit_transform(x1.values)
x_new = pd.DataFrame(x2)
x_new.columns = x1.columns
x_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.469102          1.045775    -1.521870       -0.610050  -0.145674
# 1         -0.172127          1.902404    -1.521870        0.648011   0.981105
# 2         -0.172127          1.344815    -1.242790        0.207208   0.714585
# 3          1.571351         -1.559116     1.441794       -0.610050  -0.207728
# 4         -0.469102          1.045775    -1.521870       -0.610050  -0.145674
# ...             ...               ...          ...             ...        ...
# 1453      -1.556059          0.513269    -0.977605       -0.374385   0.619516
# 1454      -1.886311          0.229325    -0.849852        0.031636  -1.120823
# 1455      -1.451955         -0.007166    -0.663895        0.207208  -0.145674
# 1456      -1.886311          0.758466    -0.725146       -0.374385  -0.207728
# 1457      -1.773110         -1.335453     1.070281        1.541281  -0.744938
#
# ...

# %%
x_new.skew()
# Out:
# fixed acidity           0.019079
# volatile acidity        0.005289
# citric acid             0.018652
# residual sugar         -0.003351
# chlorides              -0.115179
# free sulfur dioxide    -0.021273
# total sulfur dioxide   -0.005751
# density                -0.000989
# pH                     -0.000062
# sulphates               0.021132
# alcohol                 0.108436
# dtype: float64

# %%
# hence skewness removed

# %%
#now, for multicollinearity,let's check VIF

# %%
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['columns']= x_new.columns
vif
# Out:
#          vif               columns
# 0   6.851617         fixed acidity
# 1   1.962074      volatile acidity
# 2   3.027504           citric acid
# 3   1.686751        residual sugar
# 4   1.267387             chlorides
# 5   2.845234   free sulfur dioxide
# 6   3.208398  total sulfur dioxide
# 7   5.621598               density
# 8   3.147303                    pH
# 9   1.377289             sulphates
# 10  2.851448               alcohol

# %%
x_new = x_new.drop('fixed acidity',axis =1)

# %%
x_new
# Out:
#       volatile acidity  citric acid  residual sugar  chlorides  \
# 0             1.045775    -1.521870       -0.610050  -0.145674
# 1             1.902404    -1.521870        0.648011   0.981105
# 2             1.344815    -1.242790        0.207208   0.714585
# 3            -1.559116     1.441794       -0.610050  -0.207728
# 4             1.045775    -1.521870       -0.610050  -0.145674
# ...                ...          ...             ...        ...
# 1453          0.513269    -0.977605       -0.374385   0.619516
# 1454          0.229325    -0.849852        0.031636  -1.120823
# 1455         -0.007166    -0.663895        0.207208  -0.145674
# 1456          0.758466    -0.725146       -0.374385  -0.207728
# 1457         -1.335453     1.070281        1.541281  -0.744938
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.238196             -0.063312  0.635233  1.359954
# 1                1.092232              0.954919  0.056291 -0.818421
# ...

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['columns']= x_new.columns
vif
# Out:
#         vif               columns
# 0  1.961276      volatile acidity
# 1  2.813064           citric acid
# 2  1.569021        residual sugar
# 3  1.265243             chlorides
# 4  2.812227   free sulfur dioxide
# 5  3.106411  total sulfur dioxide
# 6  2.632660               density
# 7  1.537615                    pH
# 8  1.360788             sulphates
# 9  2.287543               alcohol

# %%
#multicollinearity removed

# %%
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       volatile acidity  citric acid  residual sugar  chlorides  \
# 0                0.700         0.00             1.9      0.076
# 1                0.880         0.00             2.6      0.098
# 2                0.760         0.04             2.3      0.092
# 3                0.280         0.56             1.9      0.075
# 4                0.700         0.00             1.9      0.076
# ...                ...          ...             ...        ...
# 1453             0.600         0.08             2.0      0.090
# 1454             0.550         0.10             2.2      0.062
# 1455             0.510         0.13             2.3      0.076
# 1456             0.645         0.12             2.0      0.075
# 1457             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# ...

# %%
# for scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_scaled=scaler.fit_transform(x_new)

# %%
y1.reset_index(drop=True,inplace=True)
y1
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1453    0
# 1454    0
# 1455    0
# 1456    0
# 1457    0
# Name: quality_new, Length: 1458, dtype: object

# %%
from imblearn.over_sampling import SMOTE

# %%
smt = SMOTE(0.75,k_neighbors=3)

# %%
from sklearn.model_selection import train_test_split

# %%
X,Y = smt.fit_resample(x_new,y1.astype('int64'))

# %%
x_train,y_train,x_test,y_test=train_test_split(X,Y,test_size=0.3,random_state=40)

# %%
# as this is classification problem. firstly, let's import logistic regression first

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# %%
lr=LogisticRegression()
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
dtc= DecisionTreeClassifier()
rfc=RandomForestClassifier()
svc=SVC()

# %%
def algo_state (x,y,algo):
    max_acc=0
    max_i=0
    for i in range(100):
        x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state = i)
        algo.fit(x_train,y_train)
        y_pred = algo.predict(x_test)
        acc= accuracy_score(y_test,y_pred)
        if acc> max_acc:
            max_acc=acc
            max_i = i
            i+=1
    print(f"for algo {algo}, the maximum accuracy is {max_acc} at random_state {max_i}")

# %%
algo_state(X,Y,lr)
# Out:
# for algo LogisticRegression(), the maximum accuracy is 0.8472727272727273 at random_state 9

# %%
algo_state(X,Y,dtc)
# Out:
# for algo DecisionTreeClassifier(), the maximum accuracy is 0.9290909090909091 at random_state 90

# %%
algo_state(X,Y,rfc)
# Out:
# for algo RandomForestClassifier(), the maximum accuracy is 0.9581818181818181 at random_state 91

# %%
algo_state(X,Y,svc)
# Out:
# for algo SVC(), the maximum accuracy is 0.9090909090909091 at random_state 78

# %%
from sklearn.model_selection import cross_val_score

# %%
# so, from above, rfc seems to be the best model at random_state 91. let's cross check it by cvs

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.25,random_state = 91)
rfc.fit(x_train,y_train)
y_pred = rfc.predict(x_test)
acc= accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9490909090909091

# %%
(cross_val_score(rfc,X,Y,cv=5)).mean()
# Out:
# 0.9158707806999379

# %%
# hence,our model is not overfitted.

# %%
#let's hypertune its parameters bby gridsearchcv

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'criterion':['gini','entropy'],
          'max_depth':range(5,12,1),
          'min_samples_split':range(5,10,1),
          'max_features':['sqrt','log2']
         }
grid=GridSearchCV(rfc,param_grid=params)
grid.fit(x_train,y_train)
best=grid.best_params_
print(best)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5}

# %%
rfc=RandomForestClassifier(criterion='entropy',max_depth=10,max_features='sqrt',min_samples_split=5)

# %%
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(f"accuracy is {accuracy_score(y_test,y_pred)}")
print(f"classification report is : /n {classification_report(y_test,y_pred)}")
print(f"roc_auc_score is : {roc_auc_score(y_test,y_pred)}")
# Out:
# accuracy is 0.9436363636363636
# classification report is : /n               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       294
#            1       0.93      0.95      0.94       256
#
#     accuracy                           0.94       550
#    macro avg       0.94      0.94      0.94       550
# weighted avg       0.94      0.94      0.94       550
#
# roc_auc_score is : 0.9439971301020409

# %%
# best algo for this model is RandomForestClassifier with accuracy score 94%

# %%
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(rfc,X,Y)

# %%
import pickle
filename = 'Wine_quality_project'
pickle.dump(rfc,open('filename','wb'))
