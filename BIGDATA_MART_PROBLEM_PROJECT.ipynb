# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_test=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/57854a33a5a8eebbfbf387a6a7cb20b66bd7a2d0/bigdatamart_Test.csv')
df_test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df_train=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Train.csv')
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df = pd.concat([df_train,df_test],ignore_index=True)

# %%
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    1559
# OUT013    1553
# OUT049    1550
# OUT046    1550
# OUT035    1550
# OUT045    1548
# OUT018    1546
# OUT017    1543
# OUT010     925
# OUT019     880
# Name: Outlet_Identifier, dtype: int64

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDU15    10
# FDS25    10
# FDA38    10
# FDW03    10
# FDJ10    10
#          ..
# FDR51     7
# FDM52     7
# DRN11     7
# FDH58     7
# NCW54     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import make_column_transformer

# %%
le = LabelEncoder()

# %%
df['Item_Fat_Content'] =  le.fit_transform(df['Item_Fat_Content'])
df['Item_Type']=le.fit_transform(df['Item_Type'])
df['Outlet_Type']=le.fit_transform(df['Outlet_Type'])
df['Outlet_Location_Type']=le.fit_transform(df['Outlet_Location_Type'])
df['Outlet_Size']=le.fit_transform(df['Outlet_Size'])
df['Outlet_Identifier']=le.fit_transform(df['Outlet_Identifier'])
df['Item_Identifier']=le.fit_transform(df['Item_Identifier'])

# %%
df
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                  156         9.30                 1         0.016047
# 1                    8         5.92                 2         0.019278
# 2                  662        17.50                 1         0.016760
# 3                 1121        19.20                 2         0.000000
# 4                 1297         8.93                 1         0.000000
# ...                ...          ...               ...              ...
# 14199              233        10.50                 2         0.013496
# 14200              308         7.60                 2         0.142991
# 14201             1426        10.00                 1         0.073529
# 14202              521        15.30                 2         0.000000
# 14203              997         9.50                 2         0.104720
#
#        Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
(df['Item_Visibility']==0).value_counts()
# Out:
# False    13325
# True       879
# Name: Item_Visibility, dtype: int64

# %%
df['Item_Weight']=df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                  156         9.30                 1         0.016047
# 1                    8         5.92                 2         0.019278
# 2                  662        17.50                 1         0.016760
# 3                 1121        19.20                 2         0.000000
# 4                 1297         8.93                 1         0.000000
# ...                ...          ...               ...              ...
# 14199              233        10.50                 2         0.013496
# 14200              308         7.60                 2         0.142991
# 14201             1426        10.00                 1         0.073529
# 14202              521        15.30                 2         0.000000
# 14203              997         9.50                 2         0.104720
#
#        Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
df_train1=df[0:8523]
df_test1=df[8523:]
df_train2=df[0:8523]

# %%
df_train1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_train1.dtypes
# Out:
# Item_Identifier                int32
# Item_Weight                  float64
# Item_Fat_Content               int32
# Item_Visibility              float64
# Item_Type                      int32
# Item_MRP                     float64
# Outlet_Identifier              int32
# Outlet_Establishment_Year      int64
# Outlet_Size                    int32
# Outlet_Location_Type           int32
# Outlet_Type                    int32
# Item_Outlet_Sales            float64
# dtype: object

# %%
df_train1.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
# no further encoding or imputation is required on training dataset. hance, data cleaned at first level.

# %%
df_test1
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 8523              1114    20.750000                 1         0.007565
# 8524              1078     8.300000                 4         0.038428
# 8525              1420    14.600000                 1         0.099575
# 8526               817     7.315000                 1         0.015388
# 8527              1197    12.792854                 2         0.118599
# ...                ...          ...               ...              ...
# 14199              233    10.500000                 2         0.013496
# 14200              308     7.600000                 2         0.142991
# 14201             1426    10.000000                 1         0.073529
# 14202              521    15.300000                 2         0.000000
# 14203              997     9.500000                 2         0.104720
#
#        Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_test1.reset_index(drop=True,inplace = True)
df_test1= df_test1.drop('Item_Outlet_Sales',axis=1)
df_test1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                1114    20.750000                 1         0.007565
# 1                1078     8.300000                 4         0.038428
# 2                1420    14.600000                 1         0.099575
# 3                 817     7.315000                 1         0.015388
# 4                1197    12.792854                 2         0.118599
# ...               ...          ...               ...              ...
# 5676              233    10.500000                 2         0.013496
# 5677              308     7.600000                 2         0.142991
# 5678             1426    10.000000                 1         0.073529
# 5679              521    15.300000                 2         0.000000
# 5680              997     9.500000                 2         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_test1.dtypes
# Out:
# Item_Identifier                int32
# Item_Weight                  float64
# Item_Fat_Content               int32
# Item_Visibility              float64
# Item_Type                      int32
# Item_MRP                     float64
# Outlet_Identifier              int32
# Outlet_Establishment_Year      int64
# Outlet_Size                    int32
# Outlet_Location_Type           int32
# Outlet_Type                    int32
# dtype: object

# %%
df_test1.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
# data is cleaned in testing dataset also.

# %%
# let's proceed on training dataset first.

# %%
df_train1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
# there are only four continuous type of columns. these are item_weight, item_mrp, item_visibility and outlet_establishment year. so, we need to check skewness of these columns only.

# %%
cont_train_data= df_train1[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']]

# %%
plotno=1
plt.figure(figsize=(15,15),facecolor='yellow')
for i in cont_train_data:
    plt.subplot(3,4,plotno)
    sns.distplot(cont_train_data[i])
    plt.xlabel(i)
    plotno+=1
plt.show()

# %%
# it seems there is some skewness in item_visibility and item_mrp columns.

# %%
# for ouliers.

# %%
plotno=1
plt.figure(figsize=(12,5),facecolor='orange')
for i in cont_train_data:
    plt.subplot(1,4,plotno)
    sns.boxplot(cont_train_data[i])
    plt.xlabel(i)
    plotno+=1
plt.show()

# %%
# item_visibility has outliers.

# %%
cont_train_data.skew()
# Out:
# Item_Weight                  0.098453
# Item_Visibility              1.167091
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# dtype: float64

# %%
# item_visibility has a lot of skewness.

# %%
df_train1.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.044445         -0.098114
# Item_Weight                       0.044445     1.000000         -0.017312
# Item_Fat_Content                 -0.098114    -0.017312          1.000000
# Item_Visibility                  -0.025482    -0.012582          0.034042
# Item_Type                        -0.017973     0.028022         -0.115958
# Item_MRP                          0.012853     0.024806         -0.000876
# Outlet_Identifier                -0.008602    -0.007897         -0.002357
# Outlet_Establishment_Year        -0.012772    -0.004267         -0.000189
# Outlet_Size                       0.000855    -0.014096         -0.004795
# Outlet_Location_Type              0.003656     0.003552         -0.004102
# Outlet_Type                      -0.001178    -0.002932         -0.004214
# Item_Outlet_Sales                 0.002869     0.011083          0.009800
#
# ...

# %%
sns.heatmap(df_train1.corr(),annot= True,annot_kws={'size':5})
# Out:
# <AxesSubplot:>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import zscore

# %%
((np.abs(zscore(cont_train_data)))>3).all()
# Out:
# Item_Weight                  False
# Item_Visibility              False
# Item_MRP                     False
# Outlet_Establishment_Year    False
# dtype: bool

# %%
q1= df_train1['Item_Visibility'].quantile(0.25)
q3= df_train1['Item_Visibility'].quantile(0.75)
iqr=q3-q1
high= q3+1.5*iqr
ind = np.where(df_train1['Item_Visibility']>high)
print(ind)
df_train1.drop(df_train1.index[ind[0]],inplace=True)
df_train1.reset_index(drop=True,inplace = True)
df_train1
# Out:
# (array([  49,   83,  108,  174,  334,  434,  502,  521,  532,  680,  847,
#         854,  966, 1159, 1225, 1272, 1291, 1311, 1324, 1434, 1496, 1501,
#        1560, 1575, 1644, 1651, 1754, 1805, 1827, 1841, 1941, 2081, 2088,
#        2122, 2177, 2251, 2324, 2336, 2401, 2403, 2439, 2445, 2586, 2613,
#        2728, 2855, 2895, 3001, 3017, 3171, 3206, 3336, 3341, 3399, 3458,
#        3474, 3488, 3497, 3540, 3750, 3767, 3811, 3884, 3993, 4006, 4175,
#        4192, 4219, 4350, 4382, 4408, 4530, 4538, 4567, 4656, 4674, 4789,
#        4941, 4987, 5031, 5050, 5057, 5083, 5150, 5154, 5287, 5354, 5366,
#        5374, 5445, 5634, 5732, 5734, 5784, 5795, 5837, 5880, 5891, 5946,
#        6008, 6012, 6102, 6179, 6536, 6547, 6576, 6622, 6647, 6670, 6674,
#        6786, 6833, 6903, 6909, 6926, 6953, 6966, 7005, 7030, 7072, 7081,
#        7088, 7107, 7121, 7215, 7250, 7278, 7368, 7388, 7499, 7558, 7603,
#        7639, 7744, 7866, 7949, 8194, 8215, 8273, 8292, 8345, 8371, 8432,
# ...

# %%
loss= ((8523-8379)/8379)*100
print(f'loss is {loss} %')
# Out:
# loss is 1.7185821697099892 %

# %%
#this dataloss is acceptable.

# %%
cont_train_data= df_train1[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']]

# %%
cont_train_data.skew()
# Out:
# Item_Weight                  0.097435
# Item_Visibility              0.738153
# Item_MRP                     0.129015
# Outlet_Establishment_Year   -0.414811
# dtype: float64

# %%
# let's apply power transformation on this dataset to remove skewness.

# %%
from sklearn.preprocessing import PowerTransformer

# %%
cont_train_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8374        6.865         0.056783  214.5218                       1987
# 8375        8.380         0.046982  108.1570                       2002
# 8376       10.600         0.035186   85.1224                       2004
# 8377        7.210         0.145221  103.1332                       2009
# 8378       14.800         0.044878   75.4670                       1997
#
# [8379 rows x 4 columns]

# %%
po=PowerTransformer()
lis=['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']
df_train1['Item_Weight']=po.fit_transform(df_train1[['Item_Weight']])
df_train1['Item_Visibility']=po.fit_transform(df_train1[['Item_Visibility']])
df_train1['Item_MRP']=po.fit_transform(df_train1[['Item_MRP']])
df_train1['Outlet_Establishment_Year']=po.fit_transform(df_train1[['Outlet_Establishment_Year']])
df_train1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156    -0.817488                 1        -1.139877
# 1                   8    -1.731173                 2        -1.030228
# 2                 662     1.082994                 1        -1.115421
# 3                1121     1.441110                 2        -1.732951
# 4                1297    -0.912468                 1        -1.732951
# ...               ...          ...               ...              ...
# 8374              370    -1.464183                 1         0.042580
# 8375              897    -1.055677                 2        -0.205580
# 8376             1357    -0.491680                 1        -0.532921
# 8377              681    -1.369189                 2         1.571703
# 8378               50     0.492733                 1        -0.261589
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
cont_train_data= df_train1[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']]

# %%
cont_train_data.skew()
# Out:
# Item_Weight                 -0.067617
# Item_Visibility              0.111759
# Item_MRP                    -0.114932
# Outlet_Establishment_Year   -0.218695
# dtype: float64

# %%
# hence, skewness removed

# %%
# let's quantify multicollinearity..

# %%
df_train1.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.043006         -0.098267
# Item_Weight                       0.043006     1.000000         -0.017841
# Item_Fat_Content                 -0.098267    -0.017841          1.000000
# Item_Visibility                  -0.026091    -0.007544          0.040637
# Item_Type                        -0.015801     0.029125         -0.115660
# Item_MRP                          0.015278     0.024503         -0.000680
# Outlet_Identifier                -0.009229    -0.011286         -0.001050
# Outlet_Establishment_Year        -0.014659    -0.018581          0.000231
# Outlet_Size                       0.001319    -0.015421         -0.005916
# Outlet_Location_Type              0.001969     0.008022         -0.004913
# Outlet_Type                      -0.003370     0.003782         -0.002955
# Item_Outlet_Sales                 0.001168     0.011604          0.011094
#
# ...

# %%
sns.heatmap(df_train1.corr(),annot= True,annot_kws={'size':5})
# Out:
# <AxesSubplot:>

# %%
x=df_train1.drop('Item_Outlet_Sales',axis=1)
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
vif['columns']=x.columns
vif
# Out:
#          vif                    columns
# 0   3.693126            Item_Identifier
# 1   1.003921                Item_Weight
# 2   4.822762           Item_Fat_Content
# 3   1.014956            Item_Visibility
# 4   3.671500                  Item_Type
# 5   1.001631                   Item_MRP
# 6   8.774512          Outlet_Identifier
# 7   1.231961  Outlet_Establishment_Year
# 8   5.032078                Outlet_Size
# 9   8.692730       Outlet_Location_Type
# 10  8.707884                Outlet_Type

# %%
# outlet_identifier and outlet_location_type are highly correlated with each other as seen from heatmap. also, both of them have highest values of vif. so,as outlet_location_type is least correlated with the target variable. m going to delete this.

# %%
df_train1 = df_train1.drop('Outlet_Location_Type',axis=1)

# %%
x=df_train1.drop('Item_Outlet_Sales',axis=1)
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
vif['columns']=x.columns
vif
# Out:
#         vif                    columns
# 0  3.429777            Item_Identifier
# 1  1.003748                Item_Weight
# 2  4.236564           Item_Fat_Content
# 3  1.014717            Item_Visibility
# 4  3.384154                  Item_Type
# 5  1.001630                   Item_MRP
# 6  3.680303          Outlet_Identifier
# 7  1.220765  Outlet_Establishment_Year
# 8  4.491196                Outlet_Size
# 9  3.266800                Outlet_Type

# %%
# hence, multicollinearity removed.

# %%
sns.heatmap(df_train1.corr(),annot=True,annot_kws={'size':7})
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
lr=LinearRegression()
dtr=DecisionTreeRegressor()
rfr= RandomForestRegressor()
svr=SVR()
from sklearn.model_selection import cross_val_score

# %%
df_train1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156    -0.817488                 1        -1.139877
# 1                   8    -1.731173                 2        -1.030228
# 2                 662     1.082994                 1        -1.115421
# 3                1121     1.441110                 2        -1.732951
# 4                1297    -0.912468                 1        -1.732951
# ...               ...          ...               ...              ...
# 8374              370    -1.464183                 1         0.042580
# 8375              897    -1.055677                 2        -0.205580
# 8376             1357    -0.491680                 1        -0.532921
# 8377              681    -1.369189                 2         1.571703
# 8378               50     0.492733                 1        -0.261589
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_train1['Item_Weight']=scaler.fit_transform(df_train1[['Item_Weight']])
df_train1['Item_Visibility']=scaler.fit_transform(df_train1[['Item_Visibility']])
df_train1['Item_MRP']=scaler.fit_transform(df_train1[['Item_MRP']])
df_train1['Outlet_Establishment_Year']=scaler.fit_transform(df_train1[['Outlet_Establishment_Year']])
df_train1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156    -0.817488                 1        -1.139877
# 1                   8    -1.731173                 2        -1.030228
# 2                 662     1.082994                 1        -1.115421
# 3                1121     1.441110                 2        -1.732951
# 4                1297    -0.912468                 1        -1.732951
# ...               ...          ...               ...              ...
# 8374              370    -1.464183                 1         0.042580
# 8375              897    -1.055677                 2        -0.205580
# 8376             1357    -0.491680                 1        -0.532921
# 8377              681    -1.369189                 2         1.571703
# 8378               50     0.492733                 1        -0.261589
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
x=df_train1.drop('Item_Outlet_Sales',axis=1)
y=df_train1.Item_Outlet_Sales

# %%
def algo_check (x,y,algo):
    max_acc=0
    max_i=0
    for i in range(100):
        x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state = i)
        algo.fit(x_train,y_train)
        y_pred = algo.predict(x_test)
        acc= r2_score(y_test,y_pred)
        if acc> max_acc:
            max_acc=acc
            max_i = i
            i+=1
    print(f"for algo {algo}, the maximum accuracy is {max_acc} at random_state {max_i}")

# %%
algo_check (x,y,lr)
# Out:
# for algo LinearRegression(), the maximum accuracy is 0.5320021639615404 at random_state 72

# %%
algo_check (x,y,dtr)
# Out:
# for algo DecisionTreeRegressor(), the maximum accuracy is 0.26001773591417243 at random_state 75

# %%
algo_check (x,y,rfr)
# Out:
# for algo RandomForestRegressor(), the maximum accuracy is 0.5850441978538183 at random_state 99

# %%
algo_check(x,y,svr)
# Out:
# for algo SVR(), the maximum accuracy is 0 at random_state 0

# %%
# it seems that rfr is the best algo among all the above checked algos. let's verify its overfitting.

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=99)
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.5847614399661725

# %%
cross_val_score(rfr,x,y,cv=5,scoring='r2')
# Out:
# array([0.56564859, 0.52638519, 0.51841947, 0.54554022, 0.55484405])

# %%
# hence, the model is not overfitted.

# %%
from sklearn.model_selection import GridSearchCV
from  sklearn.linear_model import Lasso,LassoCV

# %%
def lasso_check(x_train,y_train,x_test,y_test):
    lasscv = LassoCV(alphas=[0.001,0.01,0.1,1,10],max_iter = 100, normalize =True)
    lasscv.fit(x_train,y_train)
    alp=lasscv.alpha_
    lasso_reg =Lasso(alp)
    lasso_reg.fit(x_train,y_train)
    score = lasso_reg.score(x_test,y_test)
    print(f"lasso accuracy is {score}")

# %%
lasso_check(x_train,y_train,x_test,y_test)
# Out:
# lasso accuracy is 0.5236192492003713

# %%
# lasso doesn't improve r2_score much. so, we will continue to use rfr.

# %%
# hypertuning

# %%
#params = {'criterion':['squared_error', 'absolute_error'],
#         'min_samples_split':[2,3],
#         'max_depth':[5,7],
#         'min_samples_leaf':[2,4]}
#grid=GridSearchCV(rfr,param_grid = params,n_jobs=-1)
#grid.fit(x_train,y_train)
#print(grid.best_params_)

# %%
# as it took almost 3 hours but gridsearchcv didn't produce results as rfr is a heavy algo n it takes a lot of time. that's why i shifted myself to randomized searchcv.

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'criterion':['squared_error', 'absolute_error'],
         'min_samples_split':[2,3],
         'max_depth':[5,7],
         'min_samples_leaf':[2,4]}
grid=RandomizedSearchCV(rfr,param_distributions = params,n_jobs=-1)
grid.fit(x_train,y_train)
print(grid.best_params_)
# Out:
# {'min_samples_split': 3, 'min_samples_leaf': 2, 'max_depth': 5, 'criterion': 'squared_error'}

# %%
rfr1= RandomForestRegressor(criterion='squared_error',min_samples_split=3,max_depth=5,min_samples_leaf=2)

# %%
rfr1.fit(x_train,y_train)
y_pred=rfr1.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.6243751054762785

# %%
# this value of r2_score reveals that the best parameters found from randomized search cv are more accurate. so, we stick to RFR1 also with its suggested values by randomizedsearchcv.

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
rfr1.fit(x_train,y_train)
y_pred = rfr1.predict(x_test)
print(f"r2 score is {r2_score(y_test,y_pred)}")
# Out:
# r2 score is 0.6238964122937203

# %%
#RANDOM FOREST REGRESSOR ALGO is the best algo for this model with its suggested parameters by randomized searcg cv and splitting of data is taken at random_state= 99

# %%
#df_test1 = df_test1.drop('Outlet_Location_Type',axis=1)
df_test1['Item_Weight']=po.fit_transform(df_test1[['Item_Weight']])
df_test1['Item_Visibility']=po.fit_transform(df_test1[['Item_Visibility']])
df_test1['Item_MRP']=po.fit_transform(df_test1[['Item_MRP']])
df_test1['Outlet_Establishment_Year']=po.fit_transform(df_test1[['Outlet_Establishment_Year']])
df_test1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                1114     1.812461                 1        -1.501614
# 1                1078    -1.037658                 4        -0.424176
# 2                1420     0.471668                 1         0.878314
# 3                 817    -1.294766                 1        -1.192611
# 4                1197     0.055269                 2         1.143945
# ...               ...          ...               ...              ...
# 5676              233    -0.489357                 2        -1.264893
# 5677              308    -1.219495                 2         1.422421
# 5678             1426    -0.611319                 1         0.424557
# 5679              521     0.630090                 2        -1.827057
# 5680              997    -0.734722                 2         0.954967
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
# df_test1 = df_test1.drop('Outlet_Location_Type',axis=1) this code was run in the above cell for the first time when the cell was run.that's why it's producing error for the second time.

# %%
df_test1['Item_Weight']=scaler.fit_transform(df_test1[['Item_Weight']])
df_test1['Item_Visibility']=scaler.fit_transform(df_test1[['Item_Visibility']])
df_test1['Item_MRP']=scaler.fit_transform(df_test1[['Item_MRP']])
df_test1['Outlet_Establishment_Year']=scaler.fit_transform(df_test1[['Outlet_Establishment_Year']])
x_new= df_test1

# %%
y_new  = rfr.predict(x_new)
df_test1['Item_Outlet_Sales']=y_new
df_test1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                1114     1.812461                 1        -1.501614
# 1                1078    -1.037658                 4        -0.424176
# 2                1420     0.471668                 1         0.878314
# 3                 817    -1.294766                 1        -1.192611
# 4                1197     0.055269                 2         1.143945
# ...               ...          ...               ...              ...
# 5676              233    -0.489357                 2        -1.264893
# 5677              308    -1.219495                 2         1.422421
# 5678             1426    -0.611319                 1         0.424557
# 5679              521     0.630090                 2        -1.827057
# 5680              997    -0.734722                 2         0.954967
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
#df_test1 is the desired dataframe containing the item_outlet_sales as was required in the project.

# %%
# to save the model

# %%
import pickle
filename = 'BigMart_project'
pickle.dump(rfr,open('filename','wb'))

# %%
#CONCLUSION
# 1).IT'S A REGRESSION PROBLEM.
# 2).HERE, MY MODEL PREDICTS DIRECTLY THE SALES OF ITEMS PER OUTLET AS WAS REQUIRED IN TEST DATASET.
# 3).FIRSTLY, I REMOVED OUTLIERS USING IQR VALUES
# 4).THEN SKEWNESS REMOVED USING POWER TRANFORMER WITH YEO-JOHNSON METHOD
# 5).DUE TO HIGH VIF VALUES IN THE FEATURES, I DELETED ONE FEATURE AND DEVELOPED MY MODEL 
#  WITH ALL OTHER FEATURES FOR WHICH VIF VALUES ARE IN ACCEPTABLE RANGE.
# 6).I CHECKED MY MODEL WITH DIFFERENT ALGOS AND CAME TO THE CONCLUSION THAT
#  ACC. TO MY MODEL, RANDOM FOREST REGRESSOR IS THE BEST ALGO.
# 7).THE ACCURACY IN TERMS OF R2_SCORE I GOT IS IN THE RANGE OF 62% WITH 58%
#  CROSS_VAL_SCORE.
# 8).ON CHECKING BY GRIDSEARCHCV, IT DIDN'T PRODUCE ANY OUTPUT FOR ALMOST 3 HOURS 
# AND WAS STILL RUNNING. THAT'S WHY I USED RANDOMIZED SEARCH CV AND GOT BEST PARAMETERS
# WHICH IMPROVED MY RESULTS.
# 9).THEN APPLIED SAME PROCEDURE TO TEST DATASET AS REMOVED OUTLET_LOCATION_TYPE COLUMN THERE, 
# THEN APPLIED POWER TRANSFORMATION TO ITS CONTINUOUS FEATURES AND THEN APPLIED STANDARD
# SCALER TO ITS CONTINUOUUS FEATURES AND HENCE, FOUND THE REQUIRED SALES WHICH I THEN 
# APPEND IN THE TEST DATA SET AS A COLUMN WITH COLUMN NAME 'ITEM_OUTLET_SALES'.
# 10).THEN SAVED THE MODEL IN PICKLE BY NAME 'BigMart_project'
