# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
# it means no null values here in this dataset.

# %%
df['Rings'].value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: Rings, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (4177, 9)

# %%
df['Age']= df['Rings']+1.5

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings   Age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# ...

# %%
df= df.drop('Rings',axis=1)

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
# formed new target Age so that age of abalone is measured directly.
# for predicting rings, age-1.5 formula will be used.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex']= le.fit_transform(df['Sex'])

# %%
le.inverse_transform([2,1,0])
# Out:
# array(['M', 'I', 'F'], dtype=object)

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
df.dtypes
# Out:
# Sex                 int32
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Age               float64
# dtype: object

# %%
# it's a Regression Problem as the target is a continuous variable

# %%
count =1
plt.figure(figsize=(15,15),facecolor='orange')
for i in df:
    plt.subplot(3,3,count)
    sns.distplot(df[i])
    plt.xlabel(i)
    count+=1
    plt.tight_layout

# %%
# it means there is clear cut skewness in Length, Diameter, Whole weight, Shucked weight, Viscera weight and shell weight. only height feature is normally distributed as it is seen from these graphs. let's quantify thisby skew() level.

# %%
count =1
plt.figure(figsize=(15,15),facecolor='orange')
for i in df:
    plt.subplot(3,3,count)
    sns.boxplot(df[i])
    plt.xlabel(i)
    count+=1
    plt.tight_layout

# %%
# it means except sex (which is a categorical feature) all other features have outliers. shucked weight and shell weight have highest outliers

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Age               1.114102
# dtype: float64

# %%
# height is highly skewed among all. all other features are also skewed by taking threshold as +_0.5

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Age            -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight       Age
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
# surprisingly, all the features are highly correlated with each other and shell weight is the maximum correlated with target variable.

# %%
#now, let's first remove outliers.

# %%
q1=df.quantile(0.25)
q3=df.quantile(0.75)
iqr=q3-q1

# %%
df1=df

# %%
ind=[]
len_low=q1.Length-1.5*iqr.Length
ind= np.where(df1['Length']<len_low)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4123    0   0.565     0.450   0.165        0.8870          0.3700
# 4124    2   0.590     0.440   0.135        0.9660          0.4390
# 4125    2   0.600     0.475   0.205        1.1760          0.5255
# 4126    0   0.625     0.485   0.150        1.0945          0.5310
# 4127    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ind=[]
dia_low=q1.Diameter-1.5*iqr.Diameter
ind= np.where(df1['Diameter']<dia_low)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4111    0   0.565     0.450   0.165        0.8870          0.3700
# 4112    2   0.590     0.440   0.135        0.9660          0.4390
# 4113    2   0.600     0.475   0.205        1.1760          0.5255
# 4114    0   0.625     0.485   0.150        1.0945          0.5310
# 4115    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ind=[]
ht_low=q1.Height-1.5*iqr.Height
ind= np.where(df1['Height']<ht_low)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4108    0   0.565     0.450   0.165        0.8870          0.3700
# 4109    2   0.590     0.440   0.135        0.9660          0.4390
# 4110    2   0.600     0.475   0.205        1.1760          0.5255
# 4111    0   0.625     0.485   0.150        1.0945          0.5310
# 4112    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ind=[]
ht_high=q3.Height+1.5*iqr.Height
ind= np.where(df1['Height']>ht_high)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4103    0   0.565     0.450   0.165        0.8870          0.3700
# 4104    2   0.590     0.440   0.135        0.9660          0.4390
# 4105    2   0.600     0.475   0.205        1.1760          0.5255
# 4106    0   0.625     0.485   0.150        1.0945          0.5310
# 4107    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ind=[]
whwt_high=q3.xs('Whole weight') +1.5*iqr.xs('Whole weight')
ind= np.where(df1['Whole weight']>whwt_high)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4075    0   0.565     0.450   0.165        0.8870          0.3700
# 4076    2   0.590     0.440   0.135        0.9660          0.4390
# 4077    2   0.600     0.475   0.205        1.1760          0.5255
# 4078    0   0.625     0.485   0.150        1.0945          0.5310
# 4079    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ind=[]
shkdwt_high=q3.xs('Shucked weight') +1.5*iqr.xs('Shucked weight')
ind= np.where(df1['Shucked weight']>shkdwt_high)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4051    0   0.565     0.450   0.165        0.8870          0.3700
# 4052    2   0.590     0.440   0.135        0.9660          0.4390
# 4053    2   0.600     0.475   0.205        1.1760          0.5255
# 4054    0   0.625     0.485   0.150        1.0945          0.5310
# 4055    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ind=[]
vswt_high=q3.xs('Viscera weight') +1.5*iqr.xs('Viscera weight')
ind= np.where(df1['Viscera weight']>vswt_high)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4043    0   0.565     0.450   0.165        0.8870          0.3700
# 4044    2   0.590     0.440   0.135        0.9660          0.4390
# 4045    2   0.600     0.475   0.205        1.1760          0.5255
# 4046    0   0.625     0.485   0.150        1.0945          0.5310
# 4047    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ind=[]
shwt_high=q3.xs('Shell weight') +1.5*iqr.xs('Shell weight')
ind= np.where(df1['Shell weight']>shwt_high)
df1.drop(df1.index[ind],inplace=True)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4019    0   0.565     0.450   0.165        0.8870          0.3700
# 4020    2   0.590     0.440   0.135        0.9660          0.4390
# 4021    2   0.600     0.475   0.205        1.1760          0.5255
# 4022    0   0.625     0.485   0.150        1.0945          0.5310
# 4023    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
# hence, all outliers removed.

# %%
df1.skew()
# Out:
# Sex              -0.089980
# Length           -0.540556
# Diameter         -0.520150
# Height           -0.178285
# Whole weight      0.305784
# Shucked weight    0.427251
# Viscera weight    0.423178
# Shell weight      0.344314
# Age               1.207090
# dtype: float64

# %%
df1.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.042012 -0.044614 -0.048253     -0.035691
# Length         -0.042012  1.000000  0.985572  0.890340      0.939734
# Diameter       -0.044614  0.985572  1.000000  0.896929      0.938773
# Height         -0.048253  0.890340  0.896929  1.000000      0.892057
# Whole weight   -0.035691  0.939734  0.938773  0.892057      1.000000
# Shucked weight -0.017085  0.913838  0.907438  0.838584      0.967967
# Viscera weight -0.045497  0.911613  0.906869  0.868008      0.964607
# Shell weight   -0.044779  0.914868  0.922238  0.897948      0.958228
# Age            -0.034391  0.518270  0.538970  0.580034      0.518124
#
#                 Shucked weight  Viscera weight  Shell weight       Age
# Sex                  -0.017085       -0.045497     -0.044779 -0.034391
# Length                0.913838        0.911613      0.914868  0.518270
# ...

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# as sex feature has very less correlation nearly 0 with the target variable, so it will not help in predictions. hence, i m going to delete this feature.

# %%
df1 = df1.drop('Sex',axis=1)

# %%
df1
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4019   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4020   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4021   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4022   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4023   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight   Age
# ...

# %%
x=df1.drop('Age',axis =1)
y=df1['Age']
x1=df1.drop('Age',axis=1)

# %%
# for skewness removal, i m going to use power transformation here with yeo johnson method

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pow= PowerTransformer(method='yeo-johnson')

# %%
x=pow.fit_transform(x.values)

# %%
x_new = pd.DataFrame(x)
x_x = pd.DataFrame(x)

# %%
x_new.columns = x1.columns
x_x.columns = x1.columns

# %%
x_new
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.727662 -0.580526 -1.226849     -0.614736       -0.574940
# 1    -1.484462 -1.471014 -1.354770     -1.406284       -1.361280
# 2    -0.069623  0.015803 -0.155008     -0.216474       -0.392755
# 3    -0.846994 -0.580526 -0.431156     -0.609659       -0.627471
# 4    -1.608992 -1.547657 -1.606655     -1.467647       -1.429974
# ...        ...       ...       ...           ...             ...
# 4019  0.274663  0.376629  0.707052      0.256005        0.201101
# 4020  0.536024  0.253442 -0.155008      0.423569        0.527251
# 4021  0.644289  0.697737  1.937223      0.845741        0.904424
# 4022  0.924514  0.831571  0.269661      0.685676        0.927319
# 4023  1.985083  1.859835  1.620841      2.176105        2.362438
#
#       Viscera weight  Shell weight
# 0          -0.724765     -0.625014
# 1          -1.382125     -1.383858
# 2          -0.268052     -0.111277
# 3          -0.573706     -0.580507
# ...

# %%
x_new.skew()
# Out:
# Length           -0.080211
# Diameter         -0.077639
# Height           -0.016519
# Whole weight     -0.018484
# Shucked weight    0.020726
# Viscera weight    0.035036
# Shell weight      0.017736
# dtype: float64

# %%
#hence, skewness removed

# %%
#now, for multicollinearity,let's check VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['columns']= x_new.columns
vif
# Out:
#           vif         columns
# 0   33.722350          Length
# 1   32.228617        Diameter
# 2    6.381498          Height
# 3  124.471632    Whole weight
# 4   32.850413  Shucked weight
# 5   20.474585  Viscera weight
# 6   28.286607    Shell weight

# %%
# so, whole weight feature has highest vif value. let's delete this feature first and then check vif value again for multicollinearity.

# %%
x_new.drop('Whole weight',axis=1, inplace = True)
x_new
# Out:
#         Length  Diameter    Height  Shucked weight  Viscera weight  \
# 0    -0.727662 -0.580526 -1.226849       -0.574940       -0.724765
# 1    -1.484462 -1.471014 -1.354770       -1.361280       -1.382125
# 2    -0.069623  0.015803 -0.155008       -0.392755       -0.268052
# 3    -0.846994 -0.580526 -0.431156       -0.627471       -0.573706
# 4    -1.608992 -1.547657 -1.606655       -1.429974       -1.503065
# ...        ...       ...       ...             ...             ...
# 4019  0.274663  0.376629  0.707052        0.201101        0.682932
# 4020  0.536024  0.253442 -0.155008        0.527251        0.461590
# 4021  0.644289  0.697737  1.937223        0.904424        1.090740
# 4022  0.924514  0.831571  0.269661        0.927319        0.872703
# 4023  1.985083  1.859835  1.620841        2.362438        1.748249
#
#       Shell weight
# 0        -0.625014
# 1        -1.383858
# 2        -0.111277
# 3        -0.580507
# 4        -1.536758
# ...            ...
# ...

# %%
x_new.corr()
# Out:
#                   Length  Diameter    Height  Shucked weight  Viscera weight  \
# Length          1.000000  0.981084  0.877980        0.951112        0.947251
# Diameter        0.981084  1.000000  0.886280        0.943359        0.941356
# Height          0.877980  0.886280  1.000000        0.858769        0.886793
# Shucked weight  0.951112  0.943359  0.858769        1.000000        0.940822
# Viscera weight  0.947251  0.941356  0.886793        0.940822        1.000000
# Shell weight    0.943376  0.950442  0.911307        0.908654        0.930364
#
#                 Shell weight
# Length              0.943376
# Diameter            0.950442
# Height              0.911307
# Shucked weight      0.908654
# Viscera weight      0.930364
# Shell weight        1.000000

# %%
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['columns']= x_new.columns
vif
# Out:
#          vif         columns
# 0  33.682888          Length
# 1  32.188679        Diameter
# 2   6.358412          Height
# 3  12.731474  Shucked weight
# 4  13.553301  Viscera weight
# 5  14.280225    Shell weight

# %%
#now length and diameter have the highest vif values  but diameter has better correlation than length, so, i m going to delete length feature here.

# %%
x_new.drop('Length',axis=1, inplace = True)
x_new
# Out:
#       Diameter    Height  Shucked weight  Viscera weight  Shell weight
# 0    -0.580526 -1.226849       -0.574940       -0.724765     -0.625014
# 1    -1.471014 -1.354770       -1.361280       -1.382125     -1.383858
# 2     0.015803 -0.155008       -0.392755       -0.268052     -0.111277
# 3    -0.580526 -0.431156       -0.627471       -0.573706     -0.580507
# 4    -1.547657 -1.606655       -1.429974       -1.503065     -1.536758
# ...        ...       ...             ...             ...           ...
# 4019  0.376629  0.707052        0.201101        0.682932      0.200457
# 4020  0.253442 -0.155008        0.527251        0.461590      0.289302
# 4021  0.697737  1.937223        0.904424        1.090740      0.642410
# 4022  0.831571  0.269661        0.927319        0.872703      0.555242
# 4023  1.859835  1.620841        2.362438        1.748249      1.847847
#
# [4024 rows x 5 columns]

# %%
x_new.corr()
# Out:
#                 Diameter    Height  Shucked weight  Viscera weight  \
# Diameter        1.000000  0.886280        0.943359        0.941356
# Height          0.886280  1.000000        0.858769        0.886793
# Shucked weight  0.943359  0.858769        1.000000        0.940822
# Viscera weight  0.941356  0.886793        0.940822        1.000000
# Shell weight    0.950442  0.911307        0.908654        0.930364
#
#                 Shell weight
# Diameter            0.950442
# Height              0.911307
# Shucked weight      0.908654
# Viscera weight      0.930364
# Shell weight        1.000000

# %%
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['columns']= x_new.columns
vif
# Out:
#          vif         columns
# 0  17.255345        Diameter
# 1   6.327371          Height
# 2  11.715524  Shucked weight
# 3  13.066787  Viscera weight
# 4  14.121851    Shell weight

# %%
df2=df1.drop(['Whole weight','Length'],axis=1)
df2
# Out:
#       Diameter  Height  Shucked weight  Viscera weight  Shell weight   Age
# 0        0.365   0.095          0.2245          0.1010        0.1500  16.5
# 1        0.265   0.090          0.0995          0.0485        0.0700   8.5
# 2        0.420   0.135          0.2565          0.1415        0.2100  10.5
# 3        0.365   0.125          0.2155          0.1140        0.1550  11.5
# 4        0.255   0.080          0.0895          0.0395        0.0550   8.5
# ...        ...     ...             ...             ...           ...   ...
# 4019     0.450   0.165          0.3700          0.2390        0.2490  12.5
# 4020     0.440   0.135          0.4390          0.2145        0.2605  11.5
# 4021     0.475   0.205          0.5255          0.2875        0.3080  10.5
# 4022     0.485   0.150          0.5310          0.2610        0.2960  11.5
# 4023     0.555   0.195          0.9455          0.3765        0.4950  13.5
#
# [4024 rows x 6 columns]

# %%
df2.corr()
# Out:
#                 Diameter    Height  Shucked weight  Viscera weight  \
# Diameter        1.000000  0.896929        0.907438        0.906869
# Height          0.896929  1.000000        0.838584        0.868008
# Shucked weight  0.907438  0.838584        1.000000        0.926482
# Viscera weight  0.906869  0.868008        0.926482        1.000000
# Shell weight    0.922238  0.897948        0.886376        0.912466
# Age             0.538970  0.580034        0.393985        0.480864
#
#                 Shell weight       Age
# Diameter            0.922238  0.538970
# Height              0.897948  0.580034
# Shucked weight      0.886376  0.393985
# Viscera weight      0.912466  0.480864
# Shell weight        1.000000  0.606772
# Age                 0.606772  1.000000

# %%
x_new = x_new.drop('Diameter',axis=1)
x_new.corr()
# Out:
#                   Height  Shucked weight  Viscera weight  Shell weight
# Height          1.000000        0.858769        0.886793      0.911307
# Shucked weight  0.858769        1.000000        0.940822      0.908654
# Viscera weight  0.886793        0.940822        1.000000      0.930364
# Shell weight    0.911307        0.908654        0.930364      1.000000

# %%
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['columns']= x_new.columns
vif
# Out:
#          vif         columns
# 0   6.323164          Height
# 1   9.387645  Shucked weight
# 2  12.628049  Viscera weight
# 3  10.563453    Shell weight

# %%
x_new = x_new.drop('Viscera weight',axis=1)
x_new.corr()
# Out:
#                   Height  Shucked weight  Shell weight
# Height          1.000000        0.858769      0.911307
# Shucked weight  0.858769        1.000000      0.908654
# Shell weight    0.911307        0.908654      1.000000

# %%
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['columns']= x_new.columns
vif
# Out:
#         vif         columns
# 0  6.093411          Height
# 1  5.924657  Shucked weight
# 2  9.174820    Shell weight

# %%
x_new
# Out:
#         Height  Shucked weight  Shell weight
# 0    -1.226849       -0.574940     -0.625014
# 1    -1.354770       -1.361280     -1.383858
# 2    -0.155008       -0.392755     -0.111277
# 3    -0.431156       -0.627471     -0.580507
# 4    -1.606655       -1.429974     -1.536758
# ...        ...             ...           ...
# 4019  0.707052        0.201101      0.200457
# 4020 -0.155008        0.527251      0.289302
# 4021  1.937223        0.904424      0.642410
# 4022  0.269661        0.927319      0.555242
# 4023  1.620841        2.362438      1.847847
#
# [4024 rows x 3 columns]

# %%
# now vif values are in the range <10, i.e. admissible range. let's develop model now.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
x_scaled=scaler.fit_transform(x_new)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
def algo_state (x,y,algo):
    max_acc=0
    max_i=0
    for i in range(100):
        x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state = i)
        algo.fit(x_train,y_train)
        y_pred = algo.predict(x_test)
        acc= r2_score(y_test,y_pred)
        if acc> max_acc:
            max_acc=acc
            max_i = i
            i+=1
    print(f"for algo {algo}, the maximum accuracy is {max_acc} at random_state {max_i}")

# %%
algo_state(x_scaled,y,lr)
# Out:
# for algo LinearRegression(), the maximum accuracy is 0.5404295944005606 at random_state 36

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr= DecisionTreeRegressor()
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()

# %%
algo_state(x_scaled,y,dtr)
# Out:
# for algo DecisionTreeRegressor(), the maximum accuracy is 0.1639895846181859 at random_state 90

# %%
algo_state(x_scaled,y,rfr)
# Out:
# for algo RandomForestRegressor(), the maximum accuracy is 0.510751212480197 at random_state 45

# %%
#cross_val_score

# %%
from sklearn.model_selection import cross_val_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state = 36)
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.5720882639538213

# %%
cvs=cross_val_score(lr,x_scaled,y,scoring='r2',cv=5)

# %%
cvs.mean()
# Out:
# 0.3633535833527225

# %%
#it means the model is somewhat overfitted

# %%
cvs=cross_val_score(rfr,x_scaled,y,scoring='r2',cv=5)

# %%
cvs.mean()
# Out:
# 0.296590091576123

# %%
from sklearn.model_selection import GridSearchCV
from  sklearn.linear_model import Lasso,LassoCV

# %%
def lassoji(x_train,y_train,x_test,y_test):
    lasscv = LassoCV(alphas=[0.001,0.01,0.1,1,10],max_iter = 100, normalize =True)
    lasscv.fit(x_train,y_train)
    alp=lasscv.alpha_
    lasso_reg =Lasso(alp)
    lasso_reg.fit(x_train,y_train)
    score = lasso_reg.score(x_test,y_test)
    print(f"lasso accuracy is {score}")

# %%
# let's cross check by using PCA as if there is somewhat improvement in the model's overfitting problem. as pca is not particular for this but this dataset has highly correlated features, so may be there is any improvement. let's quantify this.

# %%
x_x
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.727662 -0.580526 -1.226849     -0.614736       -0.574940
# 1    -1.484462 -1.471014 -1.354770     -1.406284       -1.361280
# 2    -0.069623  0.015803 -0.155008     -0.216474       -0.392755
# 3    -0.846994 -0.580526 -0.431156     -0.609659       -0.627471
# 4    -1.608992 -1.547657 -1.606655     -1.467647       -1.429974
# ...        ...       ...       ...           ...             ...
# 4019  0.274663  0.376629  0.707052      0.256005        0.201101
# 4020  0.536024  0.253442 -0.155008      0.423569        0.527251
# 4021  0.644289  0.697737  1.937223      0.845741        0.904424
# 4022  0.924514  0.831571  0.269661      0.685676        0.927319
# 4023  1.985083  1.859835  1.620841      2.176105        2.362438
#
#       Viscera weight  Shell weight
# 0          -0.724765     -0.625014
# 1          -1.382125     -1.383858
# 2          -0.268052     -0.111277
# 3          -0.573706     -0.580507
# ...

# %%
x_x.skew()
# Out:
# Length           -0.080211
# Diameter         -0.077639
# Height           -0.016519
# Whole weight     -0.018484
# Shucked weight    0.020726
# Viscera weight    0.035036
# Shell weight      0.017736
# dtype: float64

# %%
x_x.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.981084  0.877980      0.969545        0.951112
# Diameter        0.981084  1.000000  0.886280      0.967523        0.943359
# Height          0.877980  0.886280  1.000000      0.905196        0.858769
# Whole weight    0.969545  0.967523  0.905196      1.000000        0.974228
# Shucked weight  0.951112  0.943359  0.858769      0.974228        1.000000
# Viscera weight  0.947251  0.941356  0.886793      0.971951        0.940822
# Shell weight    0.943376  0.950442  0.911307      0.966384        0.908654
#
#                 Viscera weight  Shell weight
# Length                0.947251      0.943376
# Diameter              0.941356      0.950442
# Height                0.886793      0.911307
# Whole weight          0.971951      0.966384
# Shucked weight        0.940822      0.908654
# Viscera weight        1.000000      0.930364
# Shell weight          0.930364      1.000000

# %%
from sklearn.decomposition import PCA

# %%
x_is_scaled=scaler.fit_transform(x_x)

# %%
pca = PCA()
pca.fit_transform(x_is_scaled)
# Out:
# array([[-1.90812701e+00, -5.26169342e-01, -1.64134947e-01, ...,
#          1.57734086e-01, -1.15627841e-01, -2.34239115e-02],
#        [-3.72133930e+00, -1.34970486e-03,  5.66602461e-02, ...,
#          6.41225084e-02, -1.30702694e-02,  4.76507018e-04],
#        [-4.51764407e-01,  6.25749943e-02, -2.86989015e-01, ...,
#         -1.31004715e-01, -3.60099491e-02, -4.80500440e-02],
#        ...,
#        [ 2.53646964e+00,  9.40896549e-01,  6.38935583e-01, ...,
#         -1.88737905e-01, -4.62373077e-02,  2.83858297e-02],
#        [ 1.92270648e+00, -5.40441417e-01,  4.18549109e-02, ...,
#         -1.31995044e-01,  2.87057821e-02,  9.70248116e-02],
#        [ 5.14580485e+00, -3.65538145e-01,  1.85479139e-01, ...,
#          3.43624477e-01,  6.63622286e-02, -7.49748455e-02]])

# %%
# plotting scree plot to visualize how many components are required
plt.figure(figsize = (5,5),facecolor='yellow')
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Principal Components')
plt.ylabel('Variance covered')
plt.title('PCA')
plt.show()

# %%
# two components are required for covering its more than 99% variance. so, we will choose its 2 components.

# %%
pca = PCA(n_components =2)
new_pcomp= pca.fit_transform(x_is_scaled)
pca_df = pd.DataFrame(new_pcomp,columns=['PC1','PC2'])

# %%
pca_df
# Out:
#            PC1       PC2
# 0    -1.908127 -0.526169
# 1    -3.721339 -0.001350
# 2    -0.451764  0.062575
# 3    -1.609708  0.185515
# 4    -4.042458 -0.155725
# ...        ...       ...
# 4019  1.013512  0.328324
# 4020  0.891855 -0.540399
# 4021  2.536470  0.940897
# 4022  1.922706 -0.540441
# 4023  5.145805 -0.365538
#
# [4024 rows x 2 columns]

# %%
algo_state(new_pcomp,y,lr)
# Out:
# for algo LinearRegression(), the maximum accuracy is 0.42481857403509704 at random_state 90

# %%
cvv= cross_val_score(lr,new_pcomp,y,cv=5)
cvv.mean()
# Out:
# 0.21944209529431427

# %%
# it means pca is also producing same kind of model accuracy.

# %%
# hence, we finalize the above model without pca and try to train it with other algos also.

# %%
from sklearn.ensemble import AdaBoostRegressor
abr= AdaBoostRegressor()
algo_state(x_scaled,y,abr)
# Out:
# for algo AdaBoostRegressor(), the maximum accuracy is 0.41844925482508544 at random_state 90

# %%
from sklearn.svm import SVR
svr=SVR()
algo_state(x_scaled,y,svr)
# Out:
# for algo SVR(), the maximum accuracy is 0.538886994250969 at random_state 73

# %%
x_train, x_test, y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=73)
svr.fit(x_train,y_train)
y_pred=svr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.538886994250969

# %%
lassoji(x_train,y_train,x_test,y_test)
# Out:
# lasso accuracy is 0.5373107688240344

# %%
(cross_val_score(svr,x_scaled,y,cv=5)).mean()
# Out:
# 0.43640813913822907

# %%
# svr is the best algo as it's least overfitted among all of the above algos.

# %%
# hypertuning

# %%
params = {'kernel':['linear','poly','rbf'],
         'gamma':['scale','auto'],
         'max_iter':[2,3]}
grid=GridSearchCV(svr,param_grid = params)
grid.fit(x_train,y_train)
print(grid.best_params_)
# Out:
# {'gamma': 'scale', 'kernel': 'linear', 'max_iter': 3}

# %%
svr= SVR(gamma='scale',kernel='linear',max_iter=3)

# %%
svr.fit(x_train,y_train)
y_pred=svr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# -0.9471885304926511

# %%
# this value of r2_score reveals that the best parameters found from grid search cv are not accurate. so, we stick to svr also with its default values

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
svr=SVR()
svr.fit(x_train,y_train)
y_pred = svr.predict(x_test)
print(f"r2 score is {r2_score(y_test,y_pred)}")
print(f"mean absolute error is {mean_absolute_error(y_test,y_pred)}")
print(f"mean squared error is {mean_squared_error(y_test,y_pred)}")
print(f"rmse value is {np.sqrt(mean_squared_error(y_test,y_pred))}")
# Out:
# r2 score is 0.538886994250969
# mean absolute error is 1.4887876896818482
# mean squared error is 4.6429808065416145
# rmse value is 2.1547577141158154

# %%
# SUPPORT VECTOR MACHINE ALGO is the best algo for this model with its default values and splitting of data is taken at random_state= 73

# %%
# to save the model

# %%
import pickle
filename = 'Abalone_project'
pickle.dump(svr,open('filename','wb'))

# %%
#CONCLUSION
# 1).HERE, I FORMED A NEW TARGET VARIABLE AGE = RINGS + 1.5
# 2).SO, MY MODEL PREDICTS DIRECTLY THE AGE OF ABALONE. AND IF RINGS ARE TO BE PREDICTED,
#  THEN RINGS = AGE - 1.5 CAN BE CALCULATED EASILY.
# 3).FIRSTLY, I REMOVED OUTLIERS USING IQR VALUES
# 4).THEN SKEWNESS REMOVED USING POWER TRANFORMER WITH YEO-JOHNSON METHOD
# 5).DUE TO HIGH CORRELATION IN THE FEATURES, I DELETED SOME FEATURES AND DEVELOPED MY MODEL 
#  WITH ONLY 3 FEATURES FOR WHICH VIF VALUES ARE IN ACCEPTABLE RANGE.
# 6).ALSO TRIED TO IMPROVE MY MODEL BY USING PCA (AS IT'S NOT FOR OVERFITTING
#  BUT I USED THIS BECAUSE THERE WAS HIGH CORRELATION AMONG ALL FEATURES. I USED
#  THIS TO CHECKAS ITS COMPONENTS MIGHT HELP IN REDUCING OVERFITTING). BUT IT 
#  DIDN'T HELP.SO, DEVELOPED MY MODEL WITHOUT PCA.
# 7).I CHECKED MY MODEL WITH DIFFERENT ALGOS AND CAME TO THE CONCLUSION THAT
#  ACC. TO MY MODEL, SUPPORT VECTOR MACHINE REGRESSOR IS THE BEST ALGO.
# 8).THE ACCURACY IN TERMS OF R2_SCORE I GOT IS IN THE RANGE OF 53% WITH 43%
#  CROSS_VAL_SCORE.
# 9).ON CHECKING BY GRIDSEARCHCV, I FOUND THAT SVR SHOULD BE USED WITH ITS DEFAULT
#  PARAMETERS FOR THIS MODEL.
# 10).THEN SAVED THE MODEL IN PICKLE BY NAME 'Abalone_project'
